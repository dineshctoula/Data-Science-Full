# %% [markdown]
# # 100-Day Data Science Challenge
# ## Day X: [Insert Day Topic]
#
# ---
#
# ### 📖 Study Notes
# - **Concept 1**: Key takeaways and definitions
# - **Concept 2**: Core mathematical formulations / pseudocode
# - **Concept 3**: Common pitfalls / real-world use cases
#
# ### 🧪 Practice Exercises
# Write and test your code in the cells below.

# %%
# Import standard data science packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for visualizations
sns.set_theme(style="whitegrid")
# %matplotlib inline

print("Environment ready!")

# %%
# TODO: Start coding here
